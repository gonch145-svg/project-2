# %%
import pandas as pd

df_final_experiment_clients = pd.read_csv("/Users/victoriacano/Downloads/df_final_experiment_clients.csv", sep = ';')
df_final_experiment_clients.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df_final_demo = pd.read_csv("/Users/victoriacano/Downloads/df_final_demo.csv", sep = ';')
df_final_web_data_pt_1 = pd.read_csv("/Users/victoriacano/Downloads/df_final_web_data_pt_1.csv", sep = ';')
df_final_web_data_pt_2 = pd.read_csv("/Users/victoriacano/Downloads/df_final_web_data_pt_2.csv", sep = ';')

# %%
display(df_final_demo)
display(df_final_web_data_pt_1)
display(df_final_web_data_pt_2)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...
