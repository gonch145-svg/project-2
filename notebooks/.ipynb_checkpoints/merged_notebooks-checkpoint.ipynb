# %%
import pandas as pd

df1 = pd.read_csv('../data/clean/df_final_experiment_clients_clean.csv')
df2 = pd.read_csv('../data/clean/clean_web_data.csv')
df3 = pd.read_csv('../data/clean/df_final_demo.csv')

# %%
df1.shape
# Out:
# (70609, 2)

# %%
df2.shape
# Out:
# (120157, 5)

# %%
df3.shape
# Out:
# (70594, 9)

# %%
df = df3.merge(df1, on='client_id', how='outer')

# %%
df.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0        169            21.0             262.0      47.5     M        2.0
# 1        555             3.0              46.0      29.5     U        2.0
# 2        647            12.0             151.0      57.5     M        2.0
# 3        722            11.0             143.0      59.5     F        2.0
# 4        934             9.0             109.0      51.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth variation
# 0  501570.72           4.0            4.0   Missing
# 1   25454.66           2.0            6.0      Test
# 2   30525.80           0.0            4.0      Test
# 3   22466.17           1.0            1.0   Missing
# 4   32522.88           0.0            3.0      Test

# %%
df_final = df.merge(df2, on='client_id', how='outer')

# %%
df_final.shape
# Out:
# (120157, 14)

# %%
df_final.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0        169            21.0             262.0      47.5     M        2.0
# 1        336             NaN               NaN       NaN   NaN        NaN
# 2        546             NaN               NaN       NaN   NaN        NaN
# 3        555             3.0              46.0      29.5     U        2.0
# 4        647            12.0             151.0      57.5     M        2.0
#
#          bal  calls_6_mnth  logons_6_mnth variation             visitor_id  \
# 0  501570.72           4.0            4.0   Missing  201385055_71273495308
# 1        NaN           NaN            NaN       NaN    64757908_3400128256
# 2        NaN           NaN            NaN       NaN  475037402_89828530214
# 3   25454.66           2.0            6.0      Test  402506806_56087378777
# 4   30525.80           0.0            4.0      Test   66758770_53988066587
#
#                        visit_id process_step            date_time
# 0  749567106_99161211863_557568      confirm  2017-04-12 20:23:09
# 1  649044751_80905125055_554468        start  2017-06-01 07:42:43
# 2    731811517_9330176838_94847      confirm  2017-06-17 10:05:42
# 3  637149525_38041617439_716659      confirm  2017-04-15 13:00:34
# 4   40369564_40101682850_311847      confirm  2017-04-12 15:47:45

# %%
df_final.isnull().sum()
# Out:
# client_id               0
# clnt_tenure_yr      49563
# clnt_tenure_mnth    49563
# clnt_age            49563
# gendr               49563
# num_accts           49563
# bal                 49563
# calls_6_mnth        49563
# logons_6_mnth       49563
# variation           49548
# visitor_id              0
# visit_id                0
# process_step            0
# date_time               0
# dtype: int64

# %%
df_final['variation'].unique()
# Out:
# <StringArray>
# ['Missing', nan, 'Test', 'Control']
# Length: 4, dtype: str

# %%
import numpy as np

df_final['variation'] = df_final['variation'].replace('Missing', np.nan)
df_final = df_final.dropna(subset=['variation'])

# %%
df_final.head()
# Out:
#     client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 3         555             3.0              46.0      29.5     U        2.0
# 4         647            12.0             151.0      57.5     M        2.0
# 9         934             9.0             109.0      51.0     F        2.0
# 10       1028            12.0             145.0      36.0     M        3.0
# 12       1104             5.0              66.0      48.0     U        3.0
#
#           bal  calls_6_mnth  logons_6_mnth variation             visitor_id  \
# 3    25454.66           2.0            6.0      Test  402506806_56087378777
# 4    30525.80           0.0            4.0      Test   66758770_53988066587
# 9    32522.88           0.0            3.0      Test  810392784_45004760546
# 10  103520.22           1.0            4.0   Control   42237450_62128060588
# 12  154643.94           6.0            9.0   Control  194240915_18158000533
#
#                         visit_id process_step            date_time
# 3   637149525_38041617439_716659      confirm  2017-04-15 13:00:34
# 4    40369564_40101682850_311847      confirm  2017-04-12 15:47:45
# 9     7076463_57954418406_971348        start  2017-04-18 02:38:52
# 10  557292053_87239438319_391157       step_1  2017-04-08 19:00:26
# 12   643221571_99977972121_69283        start  2017-06-20 22:31:33

# %%
groups = df_final.groupby('variation')

df_test = groups.get_group('Test')
df_control = groups.get_group('Control')

# %%
df_test.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 26968 entries, 3 to 120154
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         26968 non-null  int64
#  1   clnt_tenure_yr    26961 non-null  float64
#  2   clnt_tenure_mnth  26961 non-null  float64
#  3   clnt_age          26961 non-null  float64
#  4   gendr             26961 non-null  str
#  5   num_accts         26961 non-null  float64
#  6   bal               26961 non-null  float64
#  7   calls_6_mnth      26961 non-null  float64
#  8   logons_6_mnth     26961 non-null  float64
#  9   variation         26968 non-null  str
#  10  visitor_id        26968 non-null  str
#  11  visit_id          26968 non-null  str
#  12  process_step      26968 non-null  str
#  13  date_time         26968 non-null  str
# dtypes: float64(7), int64(1), str(6)
# memory usage: 3.1 MB

# %%
df_control.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 23532 entries, 10 to 120142
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         23532 non-null  int64
#  1   clnt_tenure_yr    23526 non-null  float64
#  2   clnt_tenure_mnth  23526 non-null  float64
#  3   clnt_age          23526 non-null  float64
#  4   gendr             23526 non-null  str
#  5   num_accts         23526 non-null  float64
#  6   bal               23526 non-null  float64
#  7   calls_6_mnth      23526 non-null  float64
#  8   logons_6_mnth     23526 non-null  float64
#  9   variation         23532 non-null  str
#  10  visitor_id        23532 non-null  str
#  11  visit_id          23532 non-null  str
#  12  process_step      23532 non-null  str
#  13  date_time         23532 non-null  str
# dtypes: float64(7), int64(1), str(6)
# memory usage: 2.7 MB

# %%
df_test.to_csv('df_test.csv', index=False)
df_control.to_csv('df_control.csv', index=False)

# %%
df_test.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  2.696800e+04    26961.000000      26961.000000  26961.000000
# mean   4.999386e+06       11.982901        149.852899     47.163922
# std    2.877455e+06        6.844947         81.783390     15.514461
# min    5.550000e+02        2.000000         33.000000     17.000000
# 25%    2.516165e+06        6.000000         82.000000     33.500000
# 50%    5.025620e+06       11.000000        134.000000     47.500000
# 75%    7.469167e+06       15.000000        191.000000     59.500000
# max    9.999832e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  26961.000000  2.696100e+04  26961.000000   26961.000000
# mean       2.249917  1.489626e+05      3.061941       6.101851
# std        0.529335  3.073737e+05      2.190590       2.177119
# min        1.000000  2.378944e+04      0.000000       3.000000
# 25%        2.000000  3.972920e+04      1.000000       4.000000
# 50%        2.000000  6.546836e+04      3.000000       6.000000
# 75%        2.000000  1.394786e+05      5.000000       8.000000
# max        7.000000  1.632004e+07      6.000000       9.000000

# %%
df_control.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  2.353200e+04    23526.000000      23526.000000  23526.000000
# mean   5.013963e+06       12.087860        151.062102     47.498427
# std    2.877470e+06        6.877626         82.127663     15.521781
# min    1.028000e+03        2.000000         33.000000     17.000000
# 25%    2.515401e+06        6.000000         82.000000     33.500000
# 50%    5.023892e+06       11.000000        137.000000     48.500000
# 75%    7.483811e+06       16.000000        192.000000     60.000000
# max    9.998921e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  23526.000000  2.352600e+04  23526.000000   23526.000000
# mean       2.259925  1.501519e+05      3.129176       6.166242
# std        0.538568  2.958124e+05      2.184541       2.173053
# min        2.000000  2.378961e+04      0.000000       3.000000
# 25%        2.000000  4.012295e+04      1.000000       4.000000
# 50%        2.000000  6.603145e+04      3.000000       6.000000
# 75%        2.000000  1.406156e+05      5.000000       8.000000
# max        7.000000  8.292996e+06      6.000000       9.000000
